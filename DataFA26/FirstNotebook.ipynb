# %% [markdown]
# # This is a header!

# %% [markdown]
# ## This is a subheader!

# %% [markdown]
# **This is bold text** *this is italic text*

# %% [markdown]
# ![Family Picture](fampic.jpeg)

# %%
x = 5

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("Hello World")
# Out:
# Hello World

# %%
#comment

# %%
def addNumbers(a, b):
    result = a+b
    return result
addNumbers (3, 4)
# Out:
# 7
