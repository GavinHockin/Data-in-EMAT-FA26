# %% [markdown]
# ## My name is Gavin Hockin and I hope to learn multiple things in this class

# %% [markdown]
# ### I hope to learn how to code better in Python

# %% [markdown]
# **I hope to learn about getting data in different forms of data**

# %% [markdown]
# _And I hope to have fun! Below is a picture of me and some of my family on a recent golf trip we went on_

# %% [markdown]
# ![Family Picture](fampic.jpeg)
